# %%
import pandas as pd

# %%
data1 = pd.read_csv(r'C:\Users\Tarun\Desktop\comp\mini-pred\MiniProjectDatasets\crop_production.csv')

# %%
data1.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             Arecanut  1254.0      2000.0
# 1  Other Kharif pulses     2.0         1.0
# 2                 Rice   102.0       321.0
# 3               Banana   176.0       641.0
# 4            Cashewnut   720.0       165.0

# %%
data1['Crop']=data1['Crop'].str.lower()

# %%
data1.Crop.unique()
# Out:
# array(['arecanut', 'other kharif pulses', 'rice', 'banana', 'cashewnut',
#        'coconut ', 'dry ginger', 'sugarcane', 'sweet potato', 'tapioca',
#        'black pepper', 'dry chillies', 'other oilseeds', 'turmeric',
#        'maize', 'moong(green gram)', 'urad', 'arhar/tur', 'groundnut',
#        'sunflower', 'bajra', 'castor seed', 'cotton(lint)', 'horse-gram',
#        'jowar', 'korra', 'ragi', 'tobacco', 'gram', 'wheat', 'masoor',
#        'sesamum', 'linseed', 'safflower', 'onion', 'other misc. pulses',
#        'samai', 'small millets', 'coriander', 'potato',
#        'other  rabi pulses', 'soyabean', 'beans & mutter(vegetable)',
#        'bhindi', 'brinjal', 'citrus fruit', 'cucumber', 'grapes', 'mango',
#        'orange', 'other fibres', 'other fresh fruits', 'other vegetables',
#        'papaya', 'pome fruit', 'tomato', 'rapeseed &mustard', 'mesta',
#        'cowpea(lobia)', 'lemon', 'pome granet', 'sapota', 'cabbage',
# ...

# %%
data1['Crop']=data1['Crop'].str.lower()

# %%
data1.head()
# Out:
#                     State_Name District_Name  Crop_Year       Season  \
# 0  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 1  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 2  Andaman and Nicobar Islands      NICOBARS       2000  Kharif
# 3  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
# 4  Andaman and Nicobar Islands      NICOBARS       2000  Whole Year
#
#                   Crop    Area  Production
# 0             arecanut  1254.0      2000.0
# 1  other kharif pulses     2.0         1.0
# 2                 rice   102.0       321.0
# 3               banana   176.0       641.0
# 4            cashewnut   720.0       165.0

# %%
data2 = pd.read_csv(r'C:\Users\Tarun\Desktop\comp\mini-pred\MiniProjectDatasets\Crop_recommendation.csv')

# %%
data2.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
data2.rename(columns = {'label':'Crop'}, inplace = True)

# %%
data2.Crop.unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
data2.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  Crop
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df=data1.merge(data2[['Crop','N','P','K','temperature','humidity','ph','rainfall']])

# %%
df.tail()
# Out:
#          State_Name District_Name  Crop_Year       Season   Crop  Area  \
# 3520395  Tamil Nadu  THE NILGIRIS       2003  Whole Year   apple   1.0
# 3520396  Tamil Nadu  THE NILGIRIS       2003  Whole Year   apple   1.0
# 3520397  Tamil Nadu  THE NILGIRIS       2003  Whole Year   apple   1.0
# 3520398  Tamil Nadu  THE NILGIRIS       2003  Whole Year   apple   1.0
# 3520399  Tamil Nadu  THE NILGIRIS       2003  Whole Year   apple   1.0
#
#          Production   N    P    K  temperature   humidity        ph  \
# 3520395         0.0  40  120  197    23.805938  92.488795  5.889481
# 3520396         0.0  25  132  198    22.319441  90.851744  5.732758
# 3520397         0.0  31  137  196    22.144641  93.825674  6.400321
# 3520398         0.0  36  144  196    23.651676  94.505288  6.496934
# 3520399         0.0  10  140  197    22.169395  90.271856  6.229499
#
#            rainfall
# 3520395  119.633555
# 3520396  100.117344
# 3520397  120.631078
# 3520398  115.361127
# 3520399  124.468311

# %%
df = df.drop_duplicates()

# %%
df = df.drop_duplicates(subset=["State_Name", "District_Name","Crop_Year"], keep="first")

# %%
df['State_Name']=df['State_Name'].str.lower()
df['District_Name']=df['District_Name'].str.lower()

# %%
df.head()
# Out:
#                       State_Name District_Name  Crop_Year       Season  Crop  \
# 0    andaman and nicobar islands      nicobars       2000  Kharif       rice
# 100  andaman and nicobar islands      nicobars       2001  Kharif       rice
# 200  andaman and nicobar islands      nicobars       2002  Kharif       rice
# 300  andaman and nicobar islands      nicobars       2003  Kharif       rice
# 400  andaman and nicobar islands      nicobars       2004  Kharif       rice
#
#        Area  Production   N   P   K  temperature   humidity        ph  \
# 0    102.00      321.00  90  42  43    20.879744  82.002744  6.502985
# 100   83.00      300.00  90  42  43    20.879744  82.002744  6.502985
# 200  189.20      510.84  90  42  43    20.879744  82.002744  6.502985
# 300   52.00       90.17  90  42  43    20.879744  82.002744  6.502985
# 400   52.94       72.57  90  42  43    20.879744  82.002744  6.502985
#
#        rainfall
# 0    202.935536
# 100  202.935536
# 200  202.935536
# ...

# %%
df.Crop.unique()
# Out:
# array(['rice', 'banana', 'maize', 'mango', 'jute'], dtype=object)

# %%
df.District_Name.unique()
# Out:
# array(['nicobars', 'north and middle andaman', 'south andamans',
#        'anantapur', 'chittoor', 'east godavari', 'guntur', 'kadapa',
#        'krishna', 'kurnool', 'prakasam', 'spsr nellore', 'srikakulam',
#        'visakhapatanam', 'vizianagaram', 'west godavari', 'anjaw',
#        'changlang', 'dibang valley', 'east kameng', 'east siang',
#        'kurung kumey', 'lohit', 'longding', 'lower dibang valley',
#        'lower subansiri', 'papum pare', 'tawang', 'tirap', 'upper siang',
#        'upper subansiri', 'west kameng', 'west siang', 'baksa', 'barpeta',
#        'bongaigaon', 'cachar', 'chirang', 'darrang', 'dhemaji', 'dhubri',
#        'dibrugarh', 'dima hasao', 'goalpara', 'golaghat', 'hailakandi',
#        'jorhat', 'kamrup', 'kamrup metro', 'karbi anglong', 'karimganj',
#        'kokrajhar', 'lakhimpur', 'marigaon', 'nagaon', 'nalbari',
#        'sivasagar', 'sonitpur', 'tinsukia', 'udalguri', 'araria', 'arwal',
# ...

# %%
df.Season.unique()
# Out:
# array(['Kharif     ', 'Autumn     ', 'Summer     ', 'Winter     ',
#        'Whole Year ', 'Rabi       '], dtype=object)

# %%
data3 = pd.read_csv(r'C:\Users\Tarun\Desktop\comp\mini-pred\MiniProjectDatasets\Ground water data.csv')

# %%
data3['Name of State']=data3['Name of State'].str.lower()
data3['Name of District']=data3['Name of District'].str.lower()

# %%
data3.head()
# Out:
#    S.no.   Name of State Name of District  \
# 0      1  andhra pradesh        anantapur
# 1      2  andhra pradesh         chittoor
# 2      3  andhra pradesh    east godavari
# 3      4  andhra pradesh           guntur
# 4      5  andhra pradesh           kadapa
#
#    Total Current Annual Ground Water Extraction  \
# 0                                     157838.79
# 1                                     104853.79
# 2                                      51106.47
# 3                                      48117.07
# 4                                      79862.47
#
#    Net Ground Water Availability for future use
# 0                                      59410.09
# 1                                      80858.36
# 2                                     193656.03
# 3                                      79051.91
# 4                                      56568.63

# %%
data3.rename(columns = {'Name of State':'State_Name','Name of District':'District_Name'}, inplace = True)

# %%
data3.head()
# Out:
#    S.no.      State_Name  District_Name  \
# 0      1  andhra pradesh      anantapur
# 1      2  andhra pradesh       chittoor
# 2      3  andhra pradesh  east godavari
# 3      4  andhra pradesh         guntur
# 4      5  andhra pradesh         kadapa
#
#    Total Current Annual Ground Water Extraction  \
# 0                                     157838.79
# 1                                     104853.79
# 2                                      51106.47
# 3                                      48117.07
# 4                                      79862.47
#
#    Net Ground Water Availability for future use
# 0                                      59410.09
# 1                                      80858.36
# 2                                     193656.03
# 3                                      79051.91
# 4                                      56568.63

# %%
df2=df.merge(data3[['State_Name','District_Name','Total Current Annual Ground Water Extraction','Net Ground Water Availability for future use']])

# %%
df2.head()
# Out:
#        State_Name District_Name  Crop_Year       Season  Crop     Area  \
# 0  andhra pradesh     anantapur       1997  Kharif       rice  35600.0
# 1  andhra pradesh     anantapur       1998  Kharif       rice  38300.0
# 2  andhra pradesh     anantapur       1999  Kharif       rice  37991.0
# 3  andhra pradesh     anantapur       2000  Kharif       rice  39905.0
# 4  andhra pradesh     anantapur       2001  Kharif       rice  32878.0
#
#    Production   N   P   K  temperature   humidity        ph    rainfall  \
# 0     75400.0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 1     96800.0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 2    105082.0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 3    117680.0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 4     95609.0  90  42  43    20.879744  82.002744  6.502985  202.935536
#
#    Total Current Annual Ground Water Extraction  \
# 0                                     157838.79
# ...

# %%
index_names = df2[df2['Crop_Year'] != 2010].index
df2.drop(index_names, inplace = True)

# %%
df2.head()
# Out:
#         State_Name  District_Name  Crop_Year       Season  Crop      Area  \
# 13  andhra pradesh      anantapur       2010  Kharif       rice   34973.0
# 31  andhra pradesh       chittoor       2010  Kharif       rice   18019.0
# 49  andhra pradesh  east godavari       2010  Kharif       rice  237640.0
# 67  andhra pradesh         guntur       2010  Kharif       rice  271072.0
# 85  andhra pradesh         kadapa       2010  Kharif       rice   53345.0
#
#     Production   N   P   K  temperature   humidity        ph    rainfall  \
# 13    102007.0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 31     53639.0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 49    457704.0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 67    649760.0  90  42  43    20.879744  82.002744  6.502985  202.935536
# 85     80657.0  90  42  43    20.879744  82.002744  6.502985  202.935536
#
#     Total Current Annual Ground Water Extraction  \
# ...

# %%
df2.State_Name.unique()
# Out:
# array(['andhra pradesh', 'arunachal pradesh', 'assam', 'bihar', 'goa',
#        'gujarat', 'haryana', 'karnataka', 'kerala', 'maharashtra',
#        'meghalaya', 'nagaland', 'odisha', 'puducherry', 'punjab',
#        'rajasthan', 'sikkim', 'tripura', 'uttarakhand', 'west bengal'],
#       dtype=object)

# %%
df2.Crop.unique()
# Out:
# array(['rice', 'maize', 'banana'], dtype=object)

# %%
df2.Season.unique()
# Out:
# array(['Kharif     ', 'Autumn     ', 'Winter     ', 'Summer     ',
#        'Whole Year ', 'Rabi       '], dtype=object)

# %%
df2.District_Name.unique()
# Out:
# array(['anantapur', 'chittoor', 'east godavari', 'guntur', 'kadapa',
#        'krishna', 'kurnool', 'prakasam', 'srikakulam', 'vizianagaram',
#        'west godavari', 'anjaw', 'changlang', 'dibang valley',
#        'east kameng', 'east siang', 'kurung kumey', 'lohit',
#        'lower dibang valley', 'lower subansiri', 'papum pare', 'tawang',
#        'tirap', 'upper siang', 'upper subansiri', 'west kameng',
#        'west siang', 'baksa', 'barpeta', 'bongaigaon', 'cachar',
#        'chirang', 'darrang', 'dhemaji', 'dhubri', 'dibrugarh',
#        'dima hasao', 'goalpara', 'golaghat', 'hailakandi', 'jorhat',
#        'kamrup', 'karbi anglong', 'karimganj', 'kokrajhar', 'lakhimpur',
#        'nagaon', 'nalbari', 'sivasagar', 'sonitpur', 'tinsukia',
#        'udalguri', 'araria', 'arwal', 'aurangabad', 'banka', 'begusarai',
#        'bhagalpur', 'bhojpur', 'buxar', 'darbhanga', 'gaya', 'gopalganj',
#        'jamui', 'jehanabad', 'katihar', 'khagaria', 'kishanganj',
# ...

# %%
df2=df2.drop(['Crop_Year'],axis=1)

# %%
df2.head()
# Out:
#         State_Name  District_Name       Season  Crop      Area  Production  \
# 13  andhra pradesh      anantapur  Kharif       rice   34973.0    102007.0
# 31  andhra pradesh       chittoor  Kharif       rice   18019.0     53639.0
# 49  andhra pradesh  east godavari  Kharif       rice  237640.0    457704.0
# 67  andhra pradesh         guntur  Kharif       rice  271072.0    649760.0
# 85  andhra pradesh         kadapa  Kharif       rice   53345.0     80657.0
#
#      N   P   K  temperature   humidity        ph    rainfall  \
# 13  90  42  43    20.879744  82.002744  6.502985  202.935536
# 31  90  42  43    20.879744  82.002744  6.502985  202.935536
# 49  90  42  43    20.879744  82.002744  6.502985  202.935536
# 67  90  42  43    20.879744  82.002744  6.502985  202.935536
# 85  90  42  43    20.879744  82.002744  6.502985  202.935536
#
#     Total Current Annual Ground Water Extraction  \
# 13                                     157838.79
# ...

# %%
df2.loc[len(df2.index)] = ['maharashtra', 'mumbai', 'Kharif','banana',9110000,634121.0,90,42,43,20.879744,82.002744,6.502985,202.935536,398000.31,53550.23]

# %%
df2=df2.drop(['State_Name'],axis=1)

# %%
df2.head()
# Out:
#     District_Name       Season  Crop      Area  Production   N   P   K  \
# 13      anantapur  Kharif       rice   34973.0    102007.0  90  42  43
# 31       chittoor  Kharif       rice   18019.0     53639.0  90  42  43
# 49  east godavari  Kharif       rice  237640.0    457704.0  90  42  43
# 67         guntur  Kharif       rice  271072.0    649760.0  90  42  43
# 85         kadapa  Kharif       rice   53345.0     80657.0  90  42  43
#
#     temperature   humidity        ph    rainfall  \
# 13    20.879744  82.002744  6.502985  202.935536
# 31    20.879744  82.002744  6.502985  202.935536
# 49    20.879744  82.002744  6.502985  202.935536
# 67    20.879744  82.002744  6.502985  202.935536
# 85    20.879744  82.002744  6.502985  202.935536
#
#     Total Current Annual Ground Water Extraction  \
# 13                                     157838.79
# 31                                     104853.79
# 49                                      51106.47
# ...

# %%
df2 = df2.drop_duplicates(subset=["District_Name"], keep="first")

# %%
df2.set_index('District_Name', inplace=True)

# %%
df2.head(5)
# Out:
#                     Season  Crop      Area  Production   N   P   K  \
# District_Name
# anantapur      Kharif       rice   34973.0    102007.0  90  42  43
# chittoor       Kharif       rice   18019.0     53639.0  90  42  43
# east godavari  Kharif       rice  237640.0    457704.0  90  42  43
# guntur         Kharif       rice  271072.0    649760.0  90  42  43
# kadapa         Kharif       rice   53345.0     80657.0  90  42  43
#
#                temperature   humidity        ph    rainfall  \
# District_Name
# anantapur        20.879744  82.002744  6.502985  202.935536
# chittoor         20.879744  82.002744  6.502985  202.935536
# east godavari    20.879744  82.002744  6.502985  202.935536
# guntur           20.879744  82.002744  6.502985  202.935536
# kadapa           20.879744  82.002744  6.502985  202.935536
#
#                Total Current Annual Ground Water Extraction  \
# District_Name
# anantapur                                         157838.79
# ...

# %%
df2.tail(5)
# Out:
#                     Season    Crop       Area  Production   N   P   K  \
# District_Name
# porbandar      Rabi          maize      500.0       900.0  71  54  16
# rajkot         Kharif        maize     6000.0      9700.0  71  54  16
# barmer         Kharif        maize        1.0         2.0  71  54  16
# sikar          Kharif        maize       14.0        25.0  71  54  16
# mumbai              Kharif  banana  9110000.0    634121.0  90  42  43
#
#                temperature   humidity        ph    rainfall  \
# District_Name
# porbandar        22.613600  63.690706  5.749914   87.759539
# rajkot           22.613600  63.690706  5.749914   87.759539
# barmer           22.613600  63.690706  5.749914   87.759539
# sikar            22.613600  63.690706  5.749914   87.759539
# mumbai           20.879744  82.002744  6.502985  202.935536
#
#                Total Current Annual Ground Water Extraction  \
# District_Name
# porbandar                                          14738.14
# ...

# %%
df2.to_json(orient='index')
# Out:
# '{"anantapur":{"Season":"Kharif     ","Crop":"rice","Area":34973.0,"Production":102007.0,"N":90,"P":42,"K":43,"temperature":20.87974371,"humidity":82.00274423,"ph":6.502985292,"rainfall":202.9355362,"Total Current Annual Ground Water Extraction":157838.79,"Net Ground Water Availability for future use":59410.09},"chittoor":{"Season":"Kharif     ","Crop":"rice","Area":18019.0,"Production":53639.0,"N":90,"P":42,"K":43,"temperature":20.87974371,"humidity":82.00274423,"ph":6.502985292,"rainfall":202.9355362,"Total Current Annual Ground Water Extraction":104853.79,"Net Ground Water Availability for future use":80858.36},"east godavari":{"Season":"Kharif     ","Crop":"rice","Area":237640.0,"Production":457704.0,"N":90,"P":42,"K":43,"temperature":20.87974371,"humidity":82.00274423,"ph":6.502985292,"rainfall":202.9355362,"Total Current Annual Ground Water Extraction":51106.47,"Net Ground Water Availability for future use":193656.03},"guntur":{"Season":"Kharif     ","Crop":"rice","Area":271072
# ...

# %%
data4 = pd.read_csv(r'C:\Users\Tarun\Desktop\comp\mini-pred\MiniProjectDatasets\pincode-dataset.csv')

# %%
data4['District']=data4['District'].str.lower()

# %%
data4.head()
# Out:
#    Pincode  District_Name StateName
# 0   110001  central delhi     Delhi
# 1   110002      new delhi     Delhi
# 2   110003    south delhi     Delhi
# 3   110004  central delhi     Delhi
# 4   110005  central delhi     Delhi

# %%
data4.rename(columns = {'District':'District_Name'}, inplace = True)

# %%
data4 = data4.drop_duplicates(subset=["District_Name"], keep="first")

# %%
data4.head()
# Out:
#     Pincode  District_Name StateName
# 0    110001  central delhi     Delhi
# 1    110002      new delhi     Delhi
# 2    110003    south delhi     Delhi
# 5    110006    north delhi     Delhi
# 14   110015     west delhi     Delhi

# %%
df_final=df2.merge(data4[['District_Name']])
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-497-5f0a6f2ab068> in <module>
# ----> 1 df_final=df2.merge(data4[['District_Name']])
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7961             copy=copy,
#    7962             indicator=indicator,
# -> 7963             validate=validate,
#    7964         )
#    7965
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      85         copy=copy,
#      86         indicator=indicator,
# ---> 87         validate=validate,
#      88     )
#      89     return op.get_result()
#
# ...
