# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\Tarun\Desktop\comp\mini-pred\MiniProjectDatasets\ICRISAT-District Level Data (2) - ICRISAT-District Level Data (2).csv')

# %%
df.head()
# Out:
#    Dist Code    Year  State_Code State_Name Dist_Name  \
# 0       67.0  2011.0         5.0  Karnataka    Mysore
# 1       68.0  2011.0         5.0  Karnataka    Mandya
# 2       73.0  2011.0         5.0  Karnataka   Bellary
# 3       75.0  2011.0         5.0  Karnataka   Belgaum
# 4       67.0  2012.0         5.0  Karnataka    Mysore
#
#    Yearwise_rainfalll (L/m2)  Ground water(HAM)  Reservoir   \
# 0                     970.54          57804.000     58123.0
# 1                     688.53          15409.000     65032.0
# 2                     640.03          15583.000     26021.0
# 3                    1438.78          27039.000     65092.0
# 4                     665.85          39400.796     59873.0
#
#    Total_Water_Availability  Water_per_hectare  Irrigatable_land
# 0               3027547.000          11.549351           262140.0
# 1               2146031.000           8.624660           248825.0
# 2               1961694.000           7.408210           264800.0
# 3               4408471.000          16.689903           264140.0
# 4               2096823.796           7.998870           262140.0

# %%
df['Year'] = pd.to_datetime(df['Year'], format='%Y')
df.head(30)
# Out:
#     Dist Code       Year  State_Code State_Name  \
# 0        67.0 2011-01-01         5.0  Karnataka
# 1        68.0 2011-01-01         5.0  Karnataka
# 2        73.0 2011-01-01         5.0  Karnataka
# 3        75.0 2011-01-01         5.0  Karnataka
# 4        67.0 2012-01-01         5.0  Karnataka
# 5        68.0 2012-01-01         5.0  Karnataka
# 6        73.0 2012-01-01         5.0  Karnataka
# 7        75.0 2012-01-01         5.0  Karnataka
# 8        67.0 2013-01-01         5.0  Karnataka
# 9        68.0 2013-01-01         5.0  Karnataka
# 10       73.0 2013-01-01         5.0  Karnataka
# 11       75.0 2013-01-01         5.0  Karnataka
# 12       67.0 2014-01-01         5.0  Karnataka
# 13       68.0 2014-01-01         5.0  Karnataka
# 14       73.0 2014-01-01         5.0  Karnataka
# 15       75.0 2014-01-01         5.0  Karnataka
# 16       67.0 2015-01-01         5.0  Karnataka
# 17       68.0 2015-01-01         5.0  Karnataka
# 18       73.0 2015-01-01         5.0  Karnataka
# 19       75.0 2015-01-01         5.0  Karnataka
# 20        NaN        NaT         NaN        NaN
# 21        NaN        NaT         NaN        NaN
# 22        NaN        NaT         NaN        NaN
# 23        NaN        NaT         NaN        NaN
# 24        NaN        NaT         NaN        NaN
#
#                             Dist_Name  Yearwise_rainfalll (L/m2)  \
# 0                              Mysore                     970.54
# 1                              Mandya                     688.53
# 2                             Bellary                     640.03
# 3                             Belgaum                    1438.78
# 4                              Mysore                     665.85
# 5                              Mandya                     478.33
# 6                             Bellary                     460.21
# 7                             Belgaum                     931.04
# 8                              Mysore                     920.94
# 9                              Mandya                     666.96
# 10                            Bellary                     682.04
# 11                            Belgaum                    1256.96
# 12                             Mysore                    1156.95
# 13                             Mandya                     820.45
# 14                            Bellary                     688.53
# 15                            Belgaum                    1503.57
# 16                             Mysore                    1074.87
# 17                             Mandya                     771.84
# 18                            Bellary                     511.88
# 19                            Belgaum                     910.02
# 20                                NaN                        NaN
# 21                                NaN                        NaN
# 22                                NaN                        NaN
# 23                                NaN                        NaN
# 24  1mm of rainfall = 10000L/hectare                         NaN
#
#     Ground water(HAM)  Reservoir   Total_Water_Availability  \
# 0          57804.0000     58123.0               3027547.000
# 1          15409.0000     65032.0               2146031.000
# 2          15583.0000     26021.0               1961694.000
# 3          27039.0000     65092.0               4408471.000
# 4          39400.7960     59873.0               2096823.796
# 5          26829.7300     63001.0               1524820.730
# 6          18197.7250     27123.0               1425950.725
# 7          26111.0305     68012.0               2887243.031
# 8          21197.5920     54879.0               2838896.592
# 9          38050.4600     64021.0               2102951.460
# 10         21012.4500     23412.0               2090544.450
# 11         24983.0610     66029.0               3861892.061
# 12         22487.7510     56789.0               3550126.751
# 13         33270.6000     61093.0               2555713.600
# 14         17093.4000     25645.0               2108328.400
# 15         26872.5400     68523.0               4606105.540
# 16         23977.9100     58123.0               3306710.910
# 17         28290.7400     63092.0               2406902.740
# 18         13374.3500     28967.0               1577981.350
# 19         28562.0200     68012.0               2826634.020
# 20                NaN         NaN                       NaN
# 21                NaN         NaN                       NaN
# 22                NaN         NaN                       NaN
# 23                NaN         NaN                       NaN
# 24                NaN         NaN                       NaN
#
#     Water_per_hectare  Irrigatable_land
# 0           11.549351           262140.0
# 1            8.624660           248825.0
# 2            7.408210           264800.0
# 3           16.689903           264140.0
# 4            7.998870           262140.0
# 5            6.128085           248825.0
# 6            5.385010           264800.0
# 7           10.930730           264140.0
# 8           10.829696           262140.0
# 9            8.451528           248825.0
# 10           7.894805           264800.0
# 11          14.620626           264140.0
# 12          13.542865           262140.0
# 13          10.271129           248825.0
# 14           7.961965           264800.0
# 15          17.438122           264140.0
# 16          12.614294           262140.0
# 17           9.673074           248825.0
# 18           9.959144           264800.0
# 19          15.701272           264140.0
# 20                NaN                NaN
# 21                NaN                NaN
# 22                NaN                NaN
# 23                NaN                NaN
# 24                NaN                NaN

# %%
df.head()
# Out:
#    Dist Code       Year  State_Code State_Name Dist_Name  \
# 0       67.0 2011-01-01         5.0  Karnataka    Mysore
# 1       68.0 2011-01-01         5.0  Karnataka    Mandya
# 2       73.0 2011-01-01         5.0  Karnataka   Bellary
# 3       75.0 2011-01-01         5.0  Karnataka   Belgaum
# 4       67.0 2012-01-01         5.0  Karnataka    Mysore
#
#    Yearwise_rainfalll (L/m2)  Ground water(HAM)  Reservoir   \
# 0                     970.54          57804.000     58123.0
# 1                     688.53          15409.000     65032.0
# 2                     640.03          15583.000     26021.0
# 3                    1438.78          27039.000     65092.0
# 4                     665.85          39400.796     59873.0
#
#    Total_Water_Availability  Water_per_hectare  Irrigatable_land
# 0               3027547.000          11.549351           262140.0
# 1               2146031.000           8.624660           248825.0
# 2               1961694.000           7.408210           264800.0
# 3               4408471.000          16.689903           264140.0
# 4               2096823.796           7.998870           262140.0

# %%
df_mysore = df[df['Dist_Name'] == 'Mysore']

# %%
from fbprophet import Prophet

# %%
# May forecasting
may = df_mysore[['Water_per_hectare','Year']]
may.columns=['y','ds']
may.head(15)
# Out:
#             y         ds
# 0   11.549351 2011-01-01
# 4    7.998870 2012-01-01
# 8   10.829696 2013-01-01
# 12  13.542865 2014-01-01
# 16  12.614294 2015-01-01

# %%
m = Prophet(interval_width=0.95)
model = m.fit(may)
future = m.make_future_dataframe(periods=3,freq='Y')
forecast = m.predict(future)
forecast.head(10)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 3.
#           ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 2011-01-01 -5.166151    7.321927   12.551414    -5.166151    -5.166151
# 1 2012-01-01 -4.541339    7.132839   12.150489    -4.541339    -4.541339
# 2 2013-01-01 -3.914814    9.874289   14.847035    -3.914814    -3.914814
# 3 2014-01-01 -3.290002    9.769760   15.064622    -3.290002    -3.290002
# 4 2015-01-01 -2.665189    9.682720   15.012163    -2.665189    -2.665189
# 5 2015-12-31 -2.042089    5.444554   10.583388    -2.042089    -2.042089
# 6 2016-12-31 -1.415564    9.215695   14.513302    -1.415565    -1.415564
# 7 2017-12-31 -0.790752    9.023331   14.133996    -0.790752    -0.790752
#
#    additive_terms  additive_terms_lower  additive_terms_upper     yearly  \
# 0       15.014168             15.014168             15.014168  15.014168
# 1       14.246684             14.246684             14.246684  14.246684
# 2       16.180628             16.180628             16.180628  16.180628
# 3       15.659077             15.659077             15.659077  15.659077
# 4       15.014168             15.014168             15.014168  15.014168
# 5        9.973972              9.973972              9.973972   9.973972
# 6       13.357618             13.357618             13.357618  13.357618
# 7       12.348170             12.348170             12.348170  12.348170
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# 0     15.014168     15.014168                   0.0
# 1     14.246684     14.246684                   0.0
# 2     16.180628     16.180628                   0.0
# 3     15.659077     15.659077                   0.0
# 4     15.014168     15.014168                   0.0
# 5      9.973972      9.973972                   0.0
# 6     13.357618     13.357618                   0.0
# 7     12.348170     12.348170                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper       yhat
# 0                         0.0                         0.0   9.848017
# 1                         0.0                         0.0   9.705346
# 2                         0.0                         0.0  12.265814
# 3                         0.0                         0.0  12.369075
# 4                         0.0                         0.0  12.348979
# 5                         0.0                         0.0   7.931883
# 6                         0.0                         0.0  11.942053
# 7                         0.0                         0.0  11.557418

# %%
plot1 = m.plot(forecast)

# %%
dict_crop={'belgaum':['Sugarcane', 'Maize',
        'Sorghum',
        'Oil_Seeds', 'Rice',
        'Groundnut', 'Wheat',
        'Soyabean'],
 'bellary': ['Rice', 'Sorghum',
        'Maize',
        'Oil_Seeds',
        'Sugarcane',
        'Groundnut',
        'Sunflower'
        ],
 'mandya': ['Sugarcane', 'Rice'
        'Oil_Seeds',
        'Sorghum',
        'Groundnut',
        'Maize'
        ],
 'mysore': ['Rice', 'Sugarcane'
        'Maize', 'Sorghum',
        'Oil_Seeds',
        'Groundnut',
        'Cotton']}

# %%
mys=dict_crop['mysore']
print(mys)
# Out:
# ['Rice', 'SugarcaneMaize', 'Sorghum', 'Oil_Seeds', 'Groundnut', 'Cotton']

# %%
data_crop=pd.read_csv(r'C:\Users\Tarun\Desktop\comp\mini-pred\MiniProjectDatasets\cropdata - Sheet1.csv')

# %%
data_crop.head(20)
# Out:
#          Crop  Unnamed: 1  Amount of water ( mm/ total growing period)     Lm2
# 0         NaN         NaN                                          NaN     NaN
# 1       Wheat         NaN                                       2731.0   4.731
# 2      Cotton         NaN                                       7000.0   9.000
# 3       Onion         NaN                                       4500.0   6.500
# 4        Rice         NaN                                       8000.0  10.000
# 5   Sugarcane         NaN                                      12700.0  14.700
# 6       Maize         NaN                                       5000.0   7.000
# 7     Sorghum         NaN                                       4500.0   6.500
# 8   Sunflower         NaN                                       6000.0   8.000
# 9    Soyabean         NaN                                       6000.0   8.000
# 10     Barley         NaN                                       3200.0   5.200
# 11   Chickpea         NaN                                       4500.0   6.500
# 12  Groundnut         NaN                                       4500.0   6.500
# 13    Mustard         NaN                                       4000.0   6.000
# 14  Oil_Seeds         NaN                                       1600.0   3.600

# %%
water=abs(forecast['yhat'].values[5])
#water=7.931883

# %%
data_crop.columns
# Out:
# Index(['Crop', 'Unnamed: 1', 'Amount of water ( mm/ total growing period)',
#        'Lm2'],
#       dtype='object')

# %%
df_mysore.dropna()
# Out:
#     Dist Code       Year  State_Code State_Name Dist_Name  \
# 0        67.0 2011-01-01         5.0  Karnataka    Mysore
# 4        67.0 2012-01-01         5.0  Karnataka    Mysore
# 8        67.0 2013-01-01         5.0  Karnataka    Mysore
# 12       67.0 2014-01-01         5.0  Karnataka    Mysore
# 16       67.0 2015-01-01         5.0  Karnataka    Mysore
#
#     Yearwise_rainfalll (L/m2)  Ground water(HAM)  Reservoir   \
# 0                      970.54          57804.000     58123.0
# 4                      665.85          39400.796     59873.0
# 8                      920.94          21197.592     54879.0
# 12                    1156.95          22487.751     56789.0
# 16                    1074.87          23977.910     58123.0
#
#     Total_Water_Availability  Water_per_hectare  Irrigatable_land
# 0                3027547.000          11.549351           262140.0
# 4                2096823.796           7.998870           262140.0
# 8                2838896.592          10.829696           262140.0
# 12               3550126.751          13.542865           262140.0
# 16               3306710.910          12.614294           262140.0

# %%
df_low_water = data_crop[data_crop["Lm2"] < water]

# %%
df_low_water.head(10)
# Out:
#          Crop  Unnamed: 1  Amount of water ( mm/ total growing period)    Lm2
# 1       Wheat         NaN                                       2731.0  4.731
# 3       Onion         NaN                                       4500.0  6.500
# 6       Maize         NaN                                       5000.0  7.000
# 7     Sorghum         NaN                                       4500.0  6.500
# 10     Barley         NaN                                       3200.0  5.200
# 11   Chickpea         NaN                                       4500.0  6.500
# 12  Groundnut         NaN                                       4500.0  6.500
# 13    Mustard         NaN                                       4000.0  6.000
# 14  Oil_Seeds         NaN                                       1600.0  3.600

# %%
df_high_water = data_crop[data_crop["Lm2"] >= water]

# %%
df_high_water.head(10)
# Out:
#         Crop  Unnamed: 1  Amount of water ( mm/ total growing period)   Lm2
# 2     Cotton         NaN                                       7000.0   9.0
# 4       Rice         NaN                                       8000.0  10.0
# 5  Sugarcane         NaN                                      12700.0  14.7
# 8  Sunflower         NaN                                       6000.0   8.0
# 9   Soyabean         NaN                                       6000.0   8.0

# %%
cant_grow_in_mysore=df_high_water['Crop'].values

# %%
cant_grow_in_mysore
# Out:
# array(['Cotton', 'Rice', 'Sugarcane', 'Sunflower', 'Soyabean'],
#       dtype=object)

# %%
can_grow_in_mysore=df_low_water['Crop'].values

# %%
can_grow_in_mysore
# Out:
# array(['Wheat', 'Onion', 'Maize', 'Sorghum', 'Barley', 'Chickpea',
#        'Groundnut', 'Mustard', 'Oil_Seeds'], dtype=object)

# %%
df_mandya = df[df['Dist_Name'] == 'Mandya']

# %%
# May forecasting
may = df_mandya[['Water_per_hectare','Year']]
may.columns=['y','ds']
may.head(15)
# Out:
#             y         ds
# 1    8.624660 2011-01-01
# 5    6.128085 2012-01-01
# 9    8.451528 2013-01-01
# 13  10.271129 2014-01-01
# 17   9.673074 2015-01-01

# %%
m = Prophet(interval_width=0.95)
model = m.fit(may)
future = m.make_future_dataframe(periods=3,freq='Y')
forecast = m.predict(future)
forecast.head(10)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 3.
#           ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 2011-01-01 -4.352822    5.496835    9.438484    -4.352822    -4.352822
# 1 2012-01-01 -3.847286    5.373403    9.102667    -3.847286    -3.847286
# 2 2013-01-01 -3.340365    7.637890   11.203654    -3.340365    -3.340365
# 3 2014-01-01 -2.834829    7.766341   11.369978    -2.834829    -2.834829
# 4 2015-01-01 -2.329292    7.842239   11.320810    -2.329292    -2.329292
# 5 2015-12-31 -1.825141    4.060519    7.549290    -1.825141    -1.825141
# 6 2016-12-31 -1.318220    7.194784   10.990778    -1.318220    -1.318220
# 7 2017-12-31 -0.812684    7.010846   10.605143    -0.812684    -0.812683
#
#    additive_terms  additive_terms_lower  additive_terms_upper     yearly  \
# 0       11.797447             11.797447             11.797447  11.797447
# 1       11.158964             11.158964             11.158964  11.158964
# 2       12.767043             12.767043             12.767043  12.767043
# 3       12.333690             12.333690             12.333690  12.333690
# 4       11.797447             11.797447             11.797447  11.797447
# 5        7.601761              7.601761              7.601761   7.601761
# 6       10.419067             10.419067             10.419067  10.419067
# 7        9.578757              9.578757              9.578757   9.578757
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# 0     11.797447     11.797447                   0.0
# 1     11.158964     11.158964                   0.0
# 2     12.767043     12.767043                   0.0
# 3     12.333690     12.333690                   0.0
# 4     11.797447     11.797447                   0.0
# 5      7.601761      7.601761                   0.0
# 6     10.419067     10.419067                   0.0
# 7      9.578757      9.578757                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                         0.0                         0.0  7.444624
# 1                         0.0                         0.0  7.311678
# 2                         0.0                         0.0  9.426678
# 3                         0.0                         0.0  9.498861
# 4                         0.0                         0.0  9.468154
# 5                         0.0                         0.0  5.776620
# 6                         0.0                         0.0  9.100847
# 7                         0.0                         0.0  8.766073

# %%
plot1 = m.plot(forecast)

# %%
mand=dict_crop['mandya']
print(mand)
# Out:
# ['Sugarcane', 'RiceOil_Seeds', 'Sorghum', 'Groundnut', 'Maize']

# %%
water_mandya=abs(forecast['yhat'].values[5])
print(water_mandya)
#water_mandya=5.776620
# Out:
# 5.776620075838604

# %%
df_mandya.dropna()
# Out:
#     Dist Code       Year  State_Code State_Name Dist_Name  \
# 1        68.0 2011-01-01         5.0  Karnataka    Mandya
# 5        68.0 2012-01-01         5.0  Karnataka    Mandya
# 9        68.0 2013-01-01         5.0  Karnataka    Mandya
# 13       68.0 2014-01-01         5.0  Karnataka    Mandya
# 17       68.0 2015-01-01         5.0  Karnataka    Mandya
#
#     Yearwise_rainfalll (L/m2)  Ground water(HAM)  Reservoir   \
# 1                      688.53           15409.00     65032.0
# 5                      478.33           26829.73     63001.0
# 9                      666.96           38050.46     64021.0
# 13                     820.45           33270.60     61093.0
# 17                     771.84           28290.74     63092.0
#
#     Total_Water_Availability  Water_per_hectare  Irrigatable_land
# 1                 2146031.00           8.624660           248825.0
# 5                 1524820.73           6.128085           248825.0
# 9                 2102951.46           8.451528           248825.0
# 13                2555713.60          10.271129           248825.0
# 17                2406902.74           9.673074           248825.0

# %%
df_low_water = data_crop[data_crop["Lm2"] < water_mandya]

# %%
df_high_water = data_crop[data_crop["Lm2"] >= water_mandya]

# %%
cant_grow_in_mandya=df_high_water['Crop'].values
print(cant_grow_in_mandya)
# Out:
# ['Cotton' 'Onion' 'Rice' 'Sugarcane' 'Maize' 'Sorghum' 'Sunflower'
#  'Soyabean' 'Chickpea' 'Groundnut' 'Mustard']

# %%
can_grow_in_mandya=df_low_water['Crop'].values
print(can_grow_in_mandya)
# Out:
# ['Wheat' 'Barley' 'Oil_Seeds']

# %%
df_belgaum = df[df['Dist_Name'] == 'Belgaum']

# %%
df_belgaum.head()
# Out:
#     Dist Code       Year  State_Code State_Name Dist_Name  \
# 3        75.0 2011-01-01         5.0  Karnataka   Belgaum
# 7        75.0 2012-01-01         5.0  Karnataka   Belgaum
# 11       75.0 2013-01-01         5.0  Karnataka   Belgaum
# 15       75.0 2014-01-01         5.0  Karnataka   Belgaum
# 19       75.0 2015-01-01         5.0  Karnataka   Belgaum
#
#     Yearwise_rainfalll (L/m2)  Ground water(HAM)  Reservoir   \
# 3                     1438.78         27039.0000     65092.0
# 7                      931.04         26111.0305     68012.0
# 11                    1256.96         24983.0610     66029.0
# 15                    1503.57         26872.5400     68523.0
# 19                     910.02         28562.0200     68012.0
#
#     Total_Water_Availability  Water_per_hectare  Irrigatable_land
# 3                4408471.000          16.689903           264140.0
# 7                2887243.031          10.930730           264140.0
# 11               3861892.061          14.620626           264140.0
# 15               4606105.540          17.438122           264140.0
# 19               2826634.020          15.701272           264140.0

# %%
# May forecasting
may = df_belgaum[['Water_per_hectare','Year']]
may.columns=['y','ds']
may.head(15)
# Out:
#             y         ds
# 3   16.689903 2011-01-01
# 7   10.930730 2012-01-01
# 11  14.620626 2013-01-01
# 15  17.438122 2014-01-01
# 19  15.701272 2015-01-01

# %%
m = Prophet(interval_width=0.95)
model = m.fit(may)
future = m.make_future_dataframe(periods=3,freq='Y')
forecast = m.predict(future)
forecast.head(10)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 3.
#           ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 2011-01-01 -6.121467   10.645614   18.005154    -6.121467    -6.121467
# 1 2012-01-01 -5.881700    9.465631   17.086324    -5.881700    -5.881700
# 2 2013-01-01 -5.641275   12.750033   20.243910    -5.641275    -5.641275
# 3 2014-01-01 -5.401507   12.535538   19.548992    -5.401507    -5.401507
# 4 2015-01-01 -5.161739   11.748287   18.904541    -5.161739    -5.161739
# 5 2015-12-31 -4.922628    4.749090   12.006674    -4.922628    -4.922628
# 6 2016-12-31 -4.682204    9.701478   17.045675    -4.682204    -4.682203
# 7 2017-12-31 -4.442436    8.125143   16.076102    -4.442436    -4.442435
#
#    additive_terms  additive_terms_lower  additive_terms_upper     yearly  \
# 0       20.383270             20.383270             20.383270  20.383270
# 1       19.247937             19.247937             19.247937  19.247937
# 2       22.207508             22.207508             22.207508  22.207508
# 3       21.370193             21.370193             21.370193  21.370193
# 4       20.383270             20.383270             20.383270  20.383270
# 5       13.255274             13.255274             13.255274  13.255274
# 6       17.965644             17.965644             17.965644  17.965644
# 7       16.538093             16.538093             16.538093  16.538093
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# 0     20.383270     20.383270                   0.0
# 1     19.247937     19.247937                   0.0
# 2     22.207508     22.207508                   0.0
# 3     21.370193     21.370193                   0.0
# 4     20.383270     20.383270                   0.0
# 5     13.255274     13.255274                   0.0
# 6     17.965644     17.965644                   0.0
# 7     16.538093     16.538093                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper       yhat
# 0                         0.0                         0.0  14.261803
# 1                         0.0                         0.0  13.366237
# 2                         0.0                         0.0  16.566233
# 3                         0.0                         0.0  15.968686
# 4                         0.0                         0.0  15.221531
# 5                         0.0                         0.0   8.332646
# 6                         0.0                         0.0  13.283440
# 7                         0.0                         0.0  12.095657

# %%
plot1 = m.plot(forecast)

# %%
belgaum=dict_crop['belgaum']
print(belgaum)
# Out:
# ['Sugarcane', 'Maize', 'Sorghum', 'Oil_Seeds', 'Rice', 'Groundnut', 'Wheat', 'Soyabean']

# %%
water_belgaum=abs(forecast['yhat'].values[5])
print(abs(water_belgaum))
#water_mandya=5.776620
# Out:
# 8.332645730497608

# %%
df_belgaum.dropna()
# Out:
#     Dist Code       Year  State_Code State_Name Dist_Name  \
# 3        75.0 2011-01-01         5.0  Karnataka   Belgaum
# 7        75.0 2012-01-01         5.0  Karnataka   Belgaum
# 11       75.0 2013-01-01         5.0  Karnataka   Belgaum
# 15       75.0 2014-01-01         5.0  Karnataka   Belgaum
# 19       75.0 2015-01-01         5.0  Karnataka   Belgaum
#
#     Yearwise_rainfalll (L/m2)  Ground water(HAM)  Reservoir   \
# 3                     1438.78         27039.0000     65092.0
# 7                      931.04         26111.0305     68012.0
# 11                    1256.96         24983.0610     66029.0
# 15                    1503.57         26872.5400     68523.0
# 19                     910.02         28562.0200     68012.0
#
#     Total_Water_Availability  Water_per_hectare  Irrigatable_land
# 3                4408471.000          16.689903           264140.0
# 7                2887243.031          10.930730           264140.0
# 11               3861892.061          14.620626           264140.0
# 15               4606105.540          17.438122           264140.0
# 19               2826634.020          15.701272           264140.0

# %%
df_low_water = data_crop[data_crop["Lm2"] < water_belgaum]

# %%
df_high_water = data_crop[data_crop["Lm2"] >= water_belgaum]

# %%
cant_grow_in_belgaum=df_high_water['Crop'].values
print(cant_grow_in_belgaum)
# Out:
# ['Cotton' 'Rice' 'Sugarcane']

# %%
can_grow_in_belgaum=df_low_water['Crop'].values
print(can_grow_in_belgaum)
# Out:
# ['Wheat' 'Onion' 'Maize' 'Sorghum' 'Sunflower' 'Soyabean' 'Barley'
#  'Chickpea' 'Groundnut' 'Mustard' 'Oil_Seeds']

# %%
df_bellary = df[df['Dist_Name'] == 'Bellary']

# %%
df_bellary.head()
# Out:
#     Dist Code       Year  State_Code State_Name Dist_Name  \
# 2        73.0 2011-01-01         5.0  Karnataka   Bellary
# 6        73.0 2012-01-01         5.0  Karnataka   Bellary
# 10       73.0 2013-01-01         5.0  Karnataka   Bellary
# 14       73.0 2014-01-01         5.0  Karnataka   Bellary
# 18       73.0 2015-01-01         5.0  Karnataka   Bellary
#
#     Yearwise_rainfalll (L/m2)  Ground water(HAM)  Reservoir   \
# 2                      640.03          15583.000     26021.0
# 6                      460.21          18197.725     27123.0
# 10                     682.04          21012.450     23412.0
# 14                     688.53          17093.400     25645.0
# 18                     511.88          13374.350     28967.0
#
#     Total_Water_Availability  Water_per_hectare  Irrigatable_land
# 2                1961694.000           7.408210           264800.0
# 6                1425950.725           5.385010           264800.0
# 10               2090544.450           7.894805           264800.0
# 14               2108328.400           7.961965           264800.0
# 18               1577981.350           9.959144           264800.0

# %%
# May forecasting
may = df_bellary[['Water_per_hectare','Year']]
may.columns=['y','ds']
may.head(15)
# Out:
#            y         ds
# 2   7.408210 2011-01-01
# 6   5.385010 2012-01-01
# 10  7.894805 2013-01-01
# 14  7.961965 2014-01-01
# 18  9.959144 2015-01-01

# %%
m = Prophet(interval_width=0.95)
model = m.fit(may)
future = m.make_future_dataframe(periods=3,freq='Y')
forecast = m.predict(future)
forecast.head(10)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 3.
#           ds     trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 2011-01-01 -2.848373    4.556544    8.014848    -2.848373    -2.848373
# 1 2012-01-01 -2.147235    4.797649    8.231689    -2.147235    -2.147235
# 2 2013-01-01 -1.444176    6.335871   10.079130    -1.444176    -1.444176
# 3 2014-01-01 -0.743038    6.779775   10.394067    -0.743038    -0.743038
# 4 2015-01-01 -0.041900    7.234110   10.670578    -0.041900    -0.041900
# 5 2015-12-31  0.657317    5.417287    8.947883     0.657317     0.657317
# 6 2016-12-31  1.360376    7.879428   11.395241     1.360376     1.360376
# 7 2017-12-31  2.061514    8.121708   11.668529     2.061514     2.061514
#
#    additive_terms  additive_terms_lower  additive_terms_upper    yearly  \
# 0        9.076974              9.076974              9.076974  9.076974
# 1        8.714789              8.714789              8.714789  8.714789
# 2        9.595332              9.595332              9.595332  9.595332
# 3        9.370604              9.370604              9.370604  9.370604
# 4        9.076974              9.076974              9.076974  9.076974
# 5        6.591511              6.591511              6.591511  6.591511
# 6        8.284512              8.284512              8.284512  8.284512
# 7        7.786723              7.786723              7.786723  7.786723
#
#    yearly_lower  yearly_upper  multiplicative_terms  \
# 0      9.076974      9.076974                   0.0
# 1      8.714789      8.714789                   0.0
# 2      9.595332      9.595332                   0.0
# 3      9.370604      9.370604                   0.0
# 4      9.076974      9.076974                   0.0
# 5      6.591511      6.591511                   0.0
# 6      8.284512      8.284512                   0.0
# 7      7.786723      7.786723                   0.0
#
#    multiplicative_terms_lower  multiplicative_terms_upper      yhat
# 0                         0.0                         0.0  6.228602
# 1                         0.0                         0.0  6.567554
# 2                         0.0                         0.0  8.151156
# 3                         0.0                         0.0  8.627566
# 4                         0.0                         0.0  9.035074
# 5                         0.0                         0.0  7.248828
# 6                         0.0                         0.0  9.644887
# 7                         0.0                         0.0  9.848236

# %%
plot1 = m.plot(forecast)

# %%
bellary=dict_crop['bellary']
print(bellary)
# Out:
# ['Rice', 'Sorghum', 'Maize', 'Oil_Seeds', 'Sugarcane', 'Groundnut', 'Sunflower']

# %%
water_bellary=abs(forecast['yhat'].values[5])
print(abs(water_bellary))
#water_mandya=5.776620
# Out:
# 7.248827533914348

# %%
df_bellary.dropna()
# Out:
#     Dist Code       Year  State_Code State_Name Dist_Name  \
# 2        73.0 2011-01-01         5.0  Karnataka   Bellary
# 6        73.0 2012-01-01         5.0  Karnataka   Bellary
# 10       73.0 2013-01-01         5.0  Karnataka   Bellary
# 14       73.0 2014-01-01         5.0  Karnataka   Bellary
# 18       73.0 2015-01-01         5.0  Karnataka   Bellary
#
#     Yearwise_rainfalll (L/m2)  Ground water(HAM)  Reservoir   \
# 2                      640.03          15583.000     26021.0
# 6                      460.21          18197.725     27123.0
# 10                     682.04          21012.450     23412.0
# 14                     688.53          17093.400     25645.0
# 18                     511.88          13374.350     28967.0
#
#     Total_Water_Availability  Water_per_hectare  Irrigatable_land
# 2                1961694.000           7.408210           264800.0
# 6                1425950.725           5.385010           264800.0
# 10               2090544.450           7.894805           264800.0
# 14               2108328.400           7.961965           264800.0
# 18               1577981.350           9.959144           264800.0

# %%
df_low_water = data_crop[data_crop["Lm2"] < water_bellary]

# %%
df_low_water
# Out:
#          Crop  Unnamed: 1  Amount of water ( mm/ total growing period)    Lm2
# 1       Wheat         NaN                                       2731.0  4.731
# 3       Onion         NaN                                       4500.0  6.500
# 6       Maize         NaN                                       5000.0  7.000
# 7     Sorghum         NaN                                       4500.0  6.500
# 10     Barley         NaN                                       3200.0  5.200
# 11   Chickpea         NaN                                       4500.0  6.500
# 12  Groundnut         NaN                                       4500.0  6.500
# 13    Mustard         NaN                                       4000.0  6.000
# 14  Oil_Seeds         NaN                                       1600.0  3.600

# %%
df_high_water = data_crop[data_crop["Lm2"] >= water_bellary]

# %%
cant_grow_in_bellary=df_high_water['Crop'].values
print(cant_grow_in_bellary)
# Out:
# ['Cotton' 'Rice' 'Sugarcane' 'Sunflower' 'Soyabean']

# %%
can_grow_in_bellary=df_low_water['Crop'].values
print(can_grow_in_bellary)
# Out:
# ['Wheat' 'Onion' 'Maize' 'Sorghum' 'Barley' 'Chickpea' 'Groundnut'
#  'Mustard' 'Oil_Seeds']
